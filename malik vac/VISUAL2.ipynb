# %%
import warnings

# %%
warnings.simplefilter('ignore')

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv("C:/Users/ADMIN/Downloads/Admission_Predict_Ver1.1 (1).csv")

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
GA.shape
# Out:
# (500, 9)

# %%
AR=GA.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR','CGPA','Research'],axis=1)

# %%
AR
# Out:
#      GRE Score  Chance of Admit
# 0          337              0.92
# 1          324              0.76
# 2          316              0.72
# 3          322              0.80
# 4          314              0.65
# ..         ...               ...
# 495        332              0.87
# 496        337              0.96
# 497        330              0.93
# 498        312              0.73
# 499        327              0.84
#
# [500 rows x 2 columns]

# %%
x=AR.iloc[:,0].values.reshape(-1,1)
y=AR.iloc[:,-1].values.reshape(-1,1)

# %%
x
# Out:
# array([[337],
#        [324],
#        [316],
#        [322],
#        [314],
#        [330],
#        [321],
#        [308],
#        [302],
#        [323],
#        [325],
#        [327],
#        [328],
#        [307],
#        [311],
#        [314],
#        [317],
#        [319],
#        [318],
#        [303],
#        [312],
#        [325],
#        [328],
#        [334],
#        [336],
#        [340],
#        [322],
#        [298],
#        [295],
#        [310],
#        [300],
#        [327],
#        [338],
#        [340],
#        [331],
#        [320],
#        [299],
#        [300],
#        [304],
#        [307],
#        [308],
#        [316],
#        [313],
#        [332],
#        [326],
#        [322],
#        [329],
#        [339],
#        [321],
#        [327],
#        [313],
#        [312],
#        [334],
#        [324],
#        [322],
#        [320],
#        [316],
#        [298],
#        [300],
#        [311],
#        [309],
#        [307],
# ...

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('GRE SCORE')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.9,random_state=0)

# %%
x_train
# Out:
# array([[306],
#        [312],
#        [305],
#        [325],
#        [309],
#        [328],
#        [295],
#        [323],
#        [305],
#        [308],
#        [296],
#        [329],
#        [307],
#        [323],
#        [319],
#        [306],
#        [325],
#        [326],
#        [299],
#        [329],
#        [331],
#        [325],
#        [312],
#        [317],
#        [320],
#        [338],
#        [325],
#        [322],
#        [297],
#        [317],
#        [309],
#        [326],
#        [300],
#        [312],
#        [327],
#        [299],
#        [321],
#        [309],
#        [302],
#        [322],
#        [313],
#        [324],
#        [311],
#        [317],
#        [307],
#        [336],
#        [316],
#        [305],
#        [309],
#        [305],
#        [338],
#        [319],
#        [336],
#        [308],
#        [321],
#        [314],
#        [320],
#        [325],
#        [305],
#        [312],
#        [294],
#        [308],
# ...

# %%
x_train.shape
# Out:
# (450, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[0.73771404],
#        [0.76806478],
#        [0.76806478],
#        [0.83888317],
#        [0.56572652],
#        [0.69724639],
#        [0.53537578],
#        [0.57584343],
#        [0.52525887],
#        [0.79841551],
#        [0.72759712],
#        [0.75794786],
#        [0.69724639],
#        [0.68712947],
#        [0.89958464],
#        [0.52525887],
#        [0.7882986 ],
#        [0.72759712],
#        [0.81864934],
#        [0.55560961],
#        [0.50502504],
#        [0.75794786],
#        [0.51514196],
#        [0.8692339 ],
#        [0.77818169],
#        [0.73771404],
#        [0.80853243],
#        [0.66689565],
#        [0.61631108],
#        [0.59607726],
#        [0.71748021],
#        [0.51514196],
#        [0.56572652],
#        [0.7882986 ],
#        [0.7073633 ],
#        [0.53537578],
#        [0.83888317],
#        [0.79841551],
#        [0.55560961],
#        [0.65677874],
#        [0.69724639],
#        [0.84900008],
#        [0.85911699],
# ...

# %%
COMP=pd.DataFrame(x_test,columns=['GRE'])

# %%
COMP
# Out:
#     GRE
# 0   318
# 1   321
# 2   321
# 3   328
# 4   301
# 5   314
# 6   298
# 7   302
# 8   297
# 9   324
# 10  317
# 11  320
# 12  314
# 13  313
# 14  334
# 15  297
# 16  323
# 17  317
# 18  326
# 19  300
# 20  295
# 21  320
# 22  296
# 23  331
# 24  322
# 25  318
# 26  325
# 27  311
# 28  306
# 29  304
# 30  316
# 31  296
# 32  301
# 33  323
# 34  315
# 35  298
# 36  328
# 37  324
# 38  300
# 39  310
# 40  314
# 41  329
# 42  330
# 43  316
# 44  327
# 45  324
# 46  333
# 47  326
# 48  309
# 49  314

# %%
COMP['CHA']=y_test

# %%
COMP
# Out:
#     GRE   CHA
# 0   318  0.64
# 1   321  0.85
# 2   321  0.80
# 3   328  0.91
# 4   301  0.68
# 5   314  0.54
# 6   298  0.54
# 7   302  0.65
# 8   297  0.52
# 9   324  0.79
# 10  317  0.65
# 11  320  0.74
# 12  314  0.64
# 13  313  0.79
# 14  334  0.89
# 15  297  0.43
# 16  323  0.81
# 17  317  0.73
# 18  326  0.80
# 19  300  0.58
# 20  295  0.57
# 21  320  0.74
# 22  296  0.60
# 23  331  0.93
# 24  322  0.88
# 25  318  0.67
# 26  325  0.70
# 27  311  0.57
# 28  306  0.48
# 29  304  0.64
# 30  316  0.69
# 31  296  0.47
# 32  301  0.57
# 33  323  0.87
# 34  315  0.39
# 35  298  0.53
# 36  328  0.84
# 37  324  0.89
# 38  300  0.63
# 39  310  0.70
# 40  314  0.72
# 41  329  0.86
# 42  330  0.91
# 43  316  0.75
# 44  327  0.74
# 45  324  0.76
# 46  333  0.96
# 47  326  0.81
# 48  309  0.60
# 49  314  0.62

# %%
COMP['PRDDATA']=y_predict

# %%
COMP
# Out:
#     GRE   CHA   PRDDATA
# 0   318  0.64  0.737714
# 1   321  0.85  0.768065
# 2   321  0.80  0.768065
# 3   328  0.91  0.838883
# 4   301  0.68  0.565727
# 5   314  0.54  0.697246
# 6   298  0.54  0.535376
# 7   302  0.65  0.575843
# 8   297  0.52  0.525259
# 9   324  0.79  0.798416
# 10  317  0.65  0.727597
# 11  320  0.74  0.757948
# 12  314  0.64  0.697246
# 13  313  0.79  0.687129
# 14  334  0.89  0.899585
# 15  297  0.43  0.525259
# 16  323  0.81  0.788299
# 17  317  0.73  0.727597
# 18  326  0.80  0.818649
# 19  300  0.58  0.555610
# 20  295  0.57  0.505025
# 21  320  0.74  0.757948
# 22  296  0.60  0.515142
# 23  331  0.93  0.869234
# 24  322  0.88  0.778182
# 25  318  0.67  0.737714
# 26  325  0.70  0.808532
# 27  311  0.57  0.666896
# 28  306  0.48  0.616311
# 29  304  0.64  0.596077
# 30  316  0.69  0.717480
# 31  296  0.47  0.515142
# 32  301  0.57  0.565727
# 33  323  0.87  0.788299
# 34  315  0.39  0.707363
# 35  298  0.53  0.535376
# 36  328  0.84  0.838883
# ...
